# %%
import random
import numpy as np

lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data
# Out:
#    whoAmI
# 0   robot
# 1   human
# 2   robot
# 3   robot
# 4   human
# 5   human
# 6   human
# 7   human
# 8   robot
# 9   robot
# 10  human
# 11  robot
# 12  human
# 13  human
# 14  robot
# 15  robot
# 16  human
# 17  robot
# 18  robot
# 19  human

# %%
def to_one_hot(row):
  if row['whoAmI'] == "robot":
    return 1
  else :
    return 0

# %%
data['robot'] = np.where(data['whoAmI']== "robot", 1, 0)
data['human'] = np.where(data['whoAmI']== "human", 1, 0)
data
# Out:
#    whoAmI  robot  human
# 0   robot      1      0
# 1   human      0      1
# 2   robot      1      0
# 3   robot      1      0
# 4   human      0      1
# 5   human      0      1
# 6   human      0      1
# 7   human      0      1
# 8   robot      1      0
# 9   robot      1      0
# 10  human      0      1
# 11  robot      1      0
# 12  human      0      1
# 13  human      0      1
# 14  robot      1      0
# 15  robot      1      0
# 16  human      0      1
# 17  robot      1      0
# 18  robot      1      0
# 19  human      0      1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['robot'].plot(kind='hist', bins=20, title='robot')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['human'].plot(kind='hist', bins=20, title='human')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data.groupby('whoAmI').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='robot', y='human', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['robot'].plot(kind='line', figsize=(8, 4), title='robot')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['human'].plot(kind='line', figsize=(8, 4), title='human')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data['whoAmI'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data, x='robot', y='whoAmI', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data['whoAmI'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data, x='human', y='whoAmI', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
